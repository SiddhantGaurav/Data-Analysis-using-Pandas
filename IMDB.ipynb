# %% [markdown]
# # IMDB analysis using Pandas

# %% [markdown]
# ## Data Import

# %%
import pandas as pd

# %%
cf=pd.read_csv('http://bit.ly/imdbratings')

# %%
pd.read_table('http://bit.ly/imdbratings')
# Out:
#     star_rating,title,content_rating,genre,duration,actors_list
# 0    9.3,The Shawshank Redemption,R,Crime,142,"[u'T...
# 1    9.2,The Godfather,R,Crime,175,"[u'Marlon Brand...
# 2    9.1,The Godfather: Part II,R,Crime,200,"[u'Al ...
# 3    9,The Dark Knight,PG-13,Action,152,"[u'Christi...
# 4    8.9,Pulp Fiction,R,Crime,154,"[u'John Travolta...
# ..                                                 ...
# 974  7.4,Tootsie,PG,Comedy,116,"[u'Dustin Hoffman',...
# 975  7.4,Back to the Future Part III,PG,Adventure,1...
# 976  7.4,Master and Commander: The Far Side of the ...
# 977  7.4,Poltergeist,PG,Horror,114,"[u'JoBeth Willi...
# 978  7.4,Wall Street,R,Crime,126,"[u'Charlie Sheen'...
#
# [979 rows x 1 columns]

# %% [markdown]
# ## Data processing

# %%
cf.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
cf.shape
# Out:
# (979, 6)

# %%
#describe all of the numeric columns
cf.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
cf.nlargest(5,'duration')
# Out:
#      star_rating                              title content_rating      genre  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
#
#      duration                                        actors_list
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %%
cf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
cf.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
type(cf.describe(include=['object']))
# Out:
# pandas.core.frame.DataFrame

# %%
cf.describe(include=['object'])
# Out:
#           title content_rating  genre  \
# count       979            976    979
# unique      975             12     16
# top     Dracula              R  Drama
# freq          2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
cf.duplicated().sum()
# Out:
# 0

# %%
cf.nunique()
# Out:
# star_rating        20
# title             975
# content_rating     12
# genre              16
# duration          133
# actors_list       969
# dtype: int64

# %%
cf.value_counts().count()
# Out:
# 976

# %%
cf.describe(include=['object'])
# Out:
#           title content_rating  genre  \
# count       979            976    979
# unique      975             12     16
# top     Dracula              R  Drama
# freq          2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
cf.sort_values(['star_rating','duration'],ascending=[True,False])
# Out:
#      star_rating                     title content_rating      genre  \
# 941          7.4          A Bridge Too Far             PG      Drama
# 968          7.4       The English Patient              R      Drama
# 955          7.4          Zero Dark Thirty              R      Drama
# 964          7.4                   Lincoln          PG-13  Biography
# 935          7.4                 Excalibur              R  Adventure
# ..           ...                       ...            ...        ...
# 5            8.9              12 Angry Men      NOT RATED      Drama
# 3            9.0           The Dark Knight          PG-13     Action
# 2            9.1    The Godfather: Part II              R      Crime
# 1            9.2             The Godfather              R      Crime
# 0            9.3  The Shawshank Redemption              R      Crime
#
#      duration                                        actors_list
# 941       175  [u'Sean Connery', u"Ryan O'Neal", u'Michael Ca...
# ...

# %%
cf['duration'].sort_values()
# Out:
# 389     64
# 338     66
# 258     67
# 293     68
# 88      68
#       ...
# 445    220
# 142    224
# 78     229
# 157    238
# 476    242
# Name: duration, Length: 979, dtype: int64

# %%
cf[cf.duration>200]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
cf[cf.duration>200].genre
# Out:
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
cf.loc[cf.duration>200,'genre']
# Out:
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
cf[(cf.duration>200) & (cf.genre=='Drama')].head()
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
#use the '|' operator to specify that a row can match any of the three criteria or we can use isin method

cf[cf.genre.isin(['Drama','Crime','Action'])].head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#Series are directly iterable (like a list)
for i in cf.title:
    print(i)
# Out:
# The Shawshank Redemption
# The Godfather
# The Godfather: Part II
# The Dark Knight
# Pulp Fiction
# 12 Angry Men
# The Good, the Bad and the Ugly
# The Lord of the Rings: The Return of the King
# Schindler's List
# Fight Club
# The Lord of the Rings: The Fellowship of the Ring
# Inception
# Star Wars: Episode V - The Empire Strikes Back
# Forrest Gump
# The Lord of the Rings: The Two Towers
# Interstellar
# One Flew Over the Cuckoo's Nest
# Seven Samurai
# Goodfellas
# Star Wars
# The Matrix
# City of God
# It's a Wonderful Life
# The Usual Suspects
# Se7en
# Life Is Beautiful
# Once Upon a Time in the West
# The Silence of the Lambs
# Leon: The Professional
# City Lights
# Spirited Away
# The Intouchables
# Casablanca
# Whiplash
# American History X
# Modern Times
# Saving Private Ryan
# Raiders of the Lost Ark
# Rear Window
# Psycho
# The Green Mile
# Sunset Blvd.
# The Pianist
# The Dark Knight Rises
# Gladiator
# Terminator 2: Judgment Day
# Memento
# Taare Zameen Par
# ...

# %%
# only include numeric columns in the DataFrame
import numpy as np
cf.select_dtypes(include=[np.number]).dtypes
# Out:
# star_rating    float64
# duration         int64
# dtype: object

# %%
cf.describe(include='all')
# Out:
#         star_rating    title content_rating  genre    duration  \
# count    979.000000      979            976    979  979.000000
# unique          NaN      975             12     16         NaN
# top             NaN  Dracula              R  Drama         NaN
# freq            NaN        2            460    278         NaN
# mean       7.889785      NaN            NaN    NaN  120.979571
# std        0.336069      NaN            NaN    NaN   26.218010
# min        7.400000      NaN            NaN    NaN   64.000000
# 25%        7.600000      NaN            NaN    NaN  102.000000
# 50%        7.800000      NaN            NaN    NaN  117.000000
# 75%        8.100000      NaN            NaN    NaN  134.000000
# max        9.300000      NaN            NaN    NaN  242.000000
#
#                                               actors_list
# count                                                 979
# unique                                                969
# ...

# %%
cf.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
cf.replace('NaN',0)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
cf
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
#average duration of film
cf[cf.genre=='Drama'].duration.mean()
# Out:
# 126.53956834532374

# %%
cf[cf['genre']=='Drama'].duration.mean()
# Out:
# 126.53956834532374

# %%
cf.groupby('genre').duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
cf.groupby('genre').duration.agg(['max','min','mean'])
# Out:
#            max  min        mean
# genre
# Action     205   80  126.485294
# Adventure  224   89  134.840000
# Animation  134   75   96.596774
# Biography  202   85  131.844156
# Comedy     187   68  107.602564
# Crime      229   67  122.298387
# Drama      242   64  126.539568
# Family     115  100  107.500000
# Fantasy    112  112  112.000000
# Film-Noir  111   88   97.333333
# History     66   66   66.000000
# Horror     146   70  102.517241
# Mystery    160   69  115.625000
# Sci-Fi     132   91  109.000000
# Thriller   120  107  114.200000
# Western    175   85  136.666667

# %% [markdown]
# ## Top genre based on the duration of movies

# %%
cf.groupby('genre').duration.agg(['max','min','mean']).plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
# display percentages instead of raw counts
cf.genre.value_counts(normalize=True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Sci-Fi       0.005107
# Thriller     0.005107
# Film-Noir    0.003064
# Family       0.002043
# History      0.001021
# Fantasy      0.001021
# Name: genre, dtype: float64

# %%
# display the unique values in the Series
cf.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
# count the number of unique values in the Series
cf.genre.nunique()
# Out:
# 16

# %%
pd.crosstab(cf.genre,cf.star_rating).head()
# Out:
# star_rating  7.4  7.5  7.6  7.7  7.8  7.9  8.0  8.1  8.2  8.3  8.4  8.5  8.6  \
# genre
# Action         4   10   25   18   21   11   10   12    4    7    4    3    2
# Adventure      7    6    6    5    9    5   12    7    2    8    3    1    0
# Animation      2    4    6    8    9    6    9    4    5    3    3    2    1
# Biography      3    8   12    8   11    9    6    8    5    2    1    1    1
# Comedy        15   14   23   25   20    9   12   14    8    4    6    3    3
#
# star_rating  8.7  8.8  8.9  9.0  9.1  9.2  9.3
# genre
# Action         2    2    0    1    0    0    0
# Adventure      1    2    1    0    0    0    0
# Animation      0    0    0    0    0    0    0
# Biography      1    0    1    0    0    0    0
# Comedy         0    0    0    0    0    0    0

# %% [markdown]
# ## Top genre based on star_rating of the movies

# %%
## compute a cross-tabulation of two Series

pd.crosstab(cf.genre,cf.star_rating).head().plot(kind='bar',figsize=(18,10))
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
cf.duration.mean()
# Out:
# 120.97957099080695

# %% [markdown]
# ## Histogram plot of movies duration

# %%
cf.duration.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#count how many times each value in the Series occurs

cf.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %% [markdown]
# ## count the types of genres in the movies

# %%
cf.genre.value_counts().plot(kind='barh',figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
cf.isnull().tail()
# Out:
#      star_rating  title  content_rating  genre  duration  actors_list
# 974        False  False           False  False     False        False
# 975        False  False           False  False     False        False
# 976        False  False           False  False     False        False
# 977        False  False           False  False     False        False
# 978        False  False           False  False     False        False

# %%
cf
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
cf.duplicated().sum()
# Out:
# 0

# %%
pd.crosstab(cf.genre,cf.content_rating).head().plot(kind='bar',figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
top_5=cf[['title','star_rating']].sort_values('star_rating',ascending=False).head()

# %% [markdown]
# ## Top 5 MOVIES with most number of star_rating ie. > than 9

# %%
top_5.plot(kind='bar',x='title',y='star_rating',figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='title'>

# %%
cf.sort_values(['star_rating','title'],ascending=[False,True]).head(5).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
👉The end 🙌🙂🎉
